# %%
print("Hello IIIT")
# Out:
# Hello IIIT

# %%
import torch
print(f"PyTorch Version: {torch.__version__}")
if torch.cuda.is_available():
    print(f"✅ SUCCESS: GPU Detected ({torch.cuda.get_device_name(0)})")
else:
    print("⚠️ WARNING: GPU not detected. Running on CPU only.")
# Out:
# PyTorch Version: 2.9.0+cu126
# ✅ SUCCESS: GPU Detected (NVIDIA GeForce RTX 3050 6GB Laptop GPU)

# %%
test
